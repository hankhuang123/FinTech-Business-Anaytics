# %% [markdown]
# # MGFD25 Assignment 1:
# ## Building your first FinTech App - The stock price notifciation app

# %% [markdown]
# Nasdaq Data Link (Quandl) is a data API specialized in providing economics and financial data.  We will be using the EOD (End of Day) feed from the Toronto Stock Exchange.  To access Quandl’s Python API, you will need to install the “Quandl Python package” first.  If the "Quandl Python package is installed correctly, you shall be able to run the following line to import:

# %% [markdown]
# ## Part 1 Retriving EOD Stock data

# %% [markdown]
# ### import libraries

# %%
pip install quandl
# Out:
# Requirement already satisfied: quandl in c:\users\ray\anaconda3\lib\site-packages (3.7.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests>=2.7.0 in c:\users\ray\anaconda3\lib\site-packages (from quandl) (2.28.1)
# Requirement already satisfied: more-itertools in c:\users\ray\anaconda3\lib\site-packages (from quandl) (9.0.0)
# Requirement already satisfied: pandas>=0.14 in c:\users\ray\anaconda3\lib\site-packages (from quandl) (1.4.4)
# Requirement already satisfied: six in c:\users\ray\anaconda3\lib\site-packages (from quandl) (1.16.0)
# Requirement already satisfied: python-dateutil in c:\users\ray\anaconda3\lib\site-packages (from quandl) (2.8.2)
# Requirement already satisfied: numpy>=1.8 in c:\users\ray\anaconda3\lib\site-packages (from quandl) (1.21.5)
# Requirement already satisfied: inflection>=0.3.1 in c:\users\ray\anaconda3\lib\site-packages (from quandl) (0.5.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ray\anaconda3\lib\site-packages (from pandas>=0.14->quandl) (2022.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ray\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ray\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ray\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ray\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (3.3)

# %%
pip install twilio
# Out:
# Requirement already satisfied: twilio in c:\users\ray\anaconda3\lib\site-packages (7.16.2)
# Requirement already satisfied: pytz in c:\users\ray\anaconda3\lib\site-packages (from twilio) (2022.1)
# Requirement already satisfied: requests>=2.0.0 in c:\users\ray\anaconda3\lib\site-packages (from twilio) (2.28.1)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.0 in c:\users\ray\anaconda3\lib\site-packages (from twilio) (2.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ray\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ray\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ray\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ray\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (2022.9.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import quandl

# %% [markdown]
# To start using the service, you will need to provide your **assigned API key**.  This is to ensure that you are the authorized person to access this data.  Please note that there is a limit of how much data you can retrieve.  Under normal circumstances you shall not have to worry about hitting the limit.  Please beware of coding errors that may lead to excessive traffic, your account can be blocked.
#
# Again, this API key is unique for each person and you must not share this key.  Whenever you are uploading your code to a shared environment, the best practice is to mask the API Key.  Meaning you don't type it out so people can see it, you'll use something called the "Environment variables", which we'll cover in later section.

# %% [markdown]
# ### Use %env to create environment variables

# %%
# %env quandl_key = 
# %env twilio_sid = 
# %env twilio_token =
# Out:
# env: quandl_key=wDHhzg1dADhphnkUyaFF
# env: twilio_sid=
# env: twilio_token=

# %% [markdown]
# ### Nasdaq Data Link demo code
# see full documentation here: https://data.nasdaq.com/tools/python

# %% [markdown]
# #### Filter by a date or range of dates

# %%
#you see I used the stored environment var instead of the acutal key code here:
quandl.ApiConfig.api_key = %env quandl_key 
ticker = 'XTSE/SHOP'
data = quandl.get(ticker, start_date='2022-12-30', end_date='2023-2-28')
display(data)
# Out:
#              Open   High    Low  Close     Volume Adjustment Factor  \


# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# slicing examples
data.iloc[-5:,:]
# Out:
#              Open   High    Low  Close     Volume Adjustment Factor  \
# Date
# 2023-02-03  68.87  73.03  68.44  70.93  6173165.0              None
# 2023-02-06  69.23  71.06  69.18  69.34  2971556.0              None
# 2023-02-07  69.43  69.73  66.38  68.82  4309337.0              None
# 2023-02-08  68.49  69.34  66.92  66.98  3810455.0              None
# 2023-02-09  68.25  68.63  66.51  66.86  4456563.0              None
#
#            Adjustment Type
# Date
# 2023-02-03            None
# 2023-02-06            None
# 2023-02-07            None
# 2023-02-08            None
# 2023-02-09            None

# %% [markdown]
# #### Select output columns (change index number to retrieve only that column)

# %%
# change index number to retrieve only that column
data = quandl.get(ticker, start_date='2022-12-31', end_date='2023-2-28', column_index = 4)
display(data)
# Out:
#             Close
# Date
# 2023-01-02  47.01
# 2023-01-03  48.79
# 2023-01-04  50.61
# 2023-01-05  49.15
# 2023-01-06  49.56
# 2023-01-09  49.81
# 2023-01-10  49.01
# 2023-01-11  48.92
# 2023-01-12  49.11
# 2023-01-13  52.09
# 2023-01-16  52.16
# 2023-01-17  53.53
# 2023-01-18  52.89
# 2023-01-19  51.29
# 2023-01-20  54.16
# 2023-01-23  58.91
# 2023-01-24  57.09
# 2023-01-25  63.34
# 2023-01-26  64.42
# 2023-01-27  66.66
# 2023-01-30  63.21
# 2023-01-31  65.57
# 2023-02-01  66.79
# 2023-02-02  71.39
# 2023-02-03  70.93
# 2023-02-06  69.34
# 2023-02-07  68.82
# 2023-02-08  66.98
# 2023-02-09  66.86

# %%
# Pandas df vs series
close = data['Close']
type(close)
close
# Out:
# Date
# 2023-01-02    47.01
# 2023-01-03    48.79
# 2023-01-04    50.61
# 2023-01-05    49.15
# 2023-01-06    49.56
# 2023-01-09    49.81
# 2023-01-10    49.01
# 2023-01-11    48.92
# 2023-01-12    49.11
# 2023-01-13    52.09
# 2023-01-16    52.16
# 2023-01-17    53.53
# 2023-01-18    52.89
# 2023-01-19    51.29
# 2023-01-20    54.16
# 2023-01-23    58.91
# 2023-01-24    57.09
# 2023-01-25    63.34
# 2023-01-26    64.42
# 2023-01-27    66.66
# 2023-01-30    63.21
# 2023-01-31    65.57
# 2023-02-01    66.79
# 2023-02-02    71.39
# 2023-02-03    70.93
# 2023-02-06    69.34
# 2023-02-07    68.82
# 2023-02-08    66.98
# 2023-02-09    66.86
# Name: Close, dtype: float64

# %%
type(close)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Retrive data for mulitple stocks

# %%
tickers = ['XTSE/BMO', 'XTSE/CM', 'XTSE/RY', 'XTSE/NA', 'XTSE/TD']
type(tickers)
# Out:
# list

# %%
# 1       XTSE/CCO     CCO-CA
# 2       XTSE/MFC     MFC-CA
# 3       XTSE/SLF     SLF-CA
# 4        XTSE/MG      MG-CA
# 5       XTSE/CNQ     CNQ-CA
# 6        XTSE/RY      RY-CA
# 7        XTSE/TD      TD-CA
# 8       XTSE/BHC     BHC-CA
# 9      XTSE/OTEX    OTEX-CA
# 10       XTSE/CM      CM-CA
# 11      XTSE/TRI     TRI-CA
# 12    XTSE/RCI_B   RCI.B-CA
# 13      XTSE/ENB     ENB-CA
# 14      XTSE/BMO     BMO-CA
# 15      XTSE/BNS     BNS-CA
# 16    XTSE/BAM_A   BAM.A-CA
# 17      XTSE/GIL     GIL-CA
# 18      XTSE/CNR     CNR-CA
# 19      XTSE/CAE     CAE-CA
# 20      XTSE/ABX     ABX-CA
# 21    XTSE/SJR_B   SJR.B-CA
# 22      XTSE/IMO     IMO-CA
# 23      XTSE/AEM     AEM-CA
# 24      XTSE/WCN     WCN-CA
# 25      XTSE/BCE     BCE-CA
# 26      XTSE/ATD     ATD-CA
# 27      XTSE/TRP     TRP-CA
# 28       XTSE/SU      SU-CA
# 29      XTSE/WPM     WPM-CA
# 30        XTSE/K       K-CA
# 31    XTSE/CTC_A   CTC.A-CA
# 32   XTSE/TECK_B  TECK.B-CA
# 33   XTSE/BIP_UN  BIP.UT-CA
# 34      XTSE/QSR     QSR-CA
# 35      XTSE/FSV     FSV-CA
# 36      XTSE/CVE     CVE-CA
# 37     XTSE/WEED    WEED-CA
# 38      XTSE/FNV     FNV-CA
# 39      XTSE/PPL     PPL-CA
# 40      XTSE/DOL     DOL-CA
# 41      XTSE/AQN     AQN-CA
# 42   XTSE/CAR_UN  CAR.UT-CA
# 43       XTSE/KL      KL-CA
# 44      XTSE/EMA     EMA-CA
# 45       XTSE/FM      FM-CA
# 46       XTSE/NA      NA-CA
# 47       XTSE/WN      WN-CA
# 48      XTSE/FTS     FTS-CA
# 49        XTSE/L       L-CA
# 50      XTSE/MRU     MRU-CA
# 51      XTSE/SNC     SNC-CA
# 52        XTSE/T       T-CA
# 53    XTSE/CCL_B   CCL.B-CA
# 54      XTSE/CSU     CSU-CA
# 55      XTSE/POW     POW-CA
# 56      XTSE/SAP     SAP-CA
# 57     XTSE/SHOP    SHOP-CA
# 58      XTSE/NTR     NTR-CA
# 59    XTSE/GIB_A   GIB.A-CA
#
#                                               Company  Unnamed: 3  Unnamed: 4  \
# 0                Canadian Pacific Kansas City Limited         NaN         NaN
# 1                                  Cameco Corporation         NaN         NaN
# 2                      Manulife Financial Corporation         NaN         NaN
# 3                             Sun Life Financial Inc.         NaN         NaN
# 4                            Magna International Inc.         NaN         NaN
# 5                  Canadian Natural Resources Limited         NaN         NaN
# 6                                Royal Bank of Canada         NaN         NaN
# 7                               Toronto-Dominion Bank         NaN         NaN
# 8                        Bausch Health Companies Inc.         NaN         NaN
# 9                               Open Text Corporation         NaN         NaN
# 10                 Canadian Imperial Bank of Commerce         NaN         NaN
# 11                        Thomson Reuters Corporation         NaN         NaN
# 12                 Rogers Communications Inc. Class B         NaN         NaN
# 13                                      Enbridge Inc.         NaN         NaN
# 14                                   Bank of Montreal         NaN         NaN
# 15                                Bank of Nova Scotia         NaN         NaN
# 16           Brookfield Asset Management Inc. Class A         NaN         NaN
# 17                             Gildan Activewear Inc.         NaN         NaN
# 18                  Canadian National Railway Company         NaN         NaN
# 19                                           CAE Inc.         NaN         NaN
# 20                           Barrick Gold Corporation         NaN         NaN
# 21                   Shaw Communications Inc. Class B         NaN         NaN
# 22                               Imperial Oil Limited         NaN         NaN
# 23                         Agnico Eagle Mines Limited         NaN         NaN
# 24                            Waste Connections, Inc.         NaN         NaN
# 25                                           BCE Inc.         NaN         NaN
# 26              Alimentation Couche-Tard Inc. Class A         NaN         NaN
# 27                              TC Energy Corporation         NaN         NaN
# 28                                 Suncor Energy Inc.         NaN         NaN
# 29                       Wheaton Precious Metals Corp         NaN         NaN
# 30                           Kinross Gold Corporation         NaN         NaN
# 31         Canadian Tire Corporation, Limited Class A         NaN         NaN
# 32                     Teck Resources Limited Class B         NaN         NaN
# 33            Brookfield Infrastructure Partners L.P.         NaN         NaN
# 34                Restaurant Brands International Inc         NaN         NaN
# 35                                  FirstService Corp         NaN         NaN
# 36                                Cenovus Energy Inc.         NaN         NaN
# 37                          Canopy Growth Corporation         NaN         NaN
# 38                          Franco-Nevada Corporation         NaN         NaN
# 39                       Pembina Pipeline Corporation         NaN         NaN
# 40                                     Dollarama Inc.         NaN         NaN
# 41                  Algonquin Power & Utilities Corp.         NaN         NaN
# 42  Canadian Apartment Properties Real Estate Inve...         NaN         NaN
# 43                            Kirkland Lake Gold Ltd.         NaN         NaN
# 44                                 Emera Incorporated         NaN         NaN
# 45                        First Quantum Minerals Ltd.         NaN         NaN
# 46                            National Bank of Canada         NaN         NaN
# 47                              George Weston Limited         NaN         NaN
# 48                                        Fortis Inc.         NaN         NaN
# 49                           Loblaw Companies Limited         NaN         NaN
# 50                                         Metro Inc.         NaN         NaN
# 51                             SNC-Lavalin Group Inc.         NaN         NaN
# 52                                  TELUS Corporation         NaN         NaN
# 53                        CCL Industries Inc. Class B         NaN         NaN
# 54                        Constellation Software Inc.         NaN         NaN
# 55                        Power Corporation of Canada         NaN         NaN
# 56                                        Saputo Inc.         NaN         NaN
# 57                              Shopify, Inc. Class A         NaN         NaN
# 58                                       Nutrien Ltd.         NaN         NaN
# 59                                   CGI Inc. Class A         NaN         NaN
#
#     Unnamed: 5  Unnamed: 6  Unnamed: 7 Unnamed: 8
# 0          NaN         NaN         NaN        NaN
# 1          NaN         NaN         NaN        NaN
# 2          NaN         NaN         NaN        NaN
# 3          NaN         NaN         NaN        NaN
# 4          NaN         NaN         NaN        NaN
# 5          NaN         NaN         NaN        NaN
# 6          NaN         NaN         NaN        NaN
# 7          NaN         NaN         NaN        NaN
# 8          NaN         NaN         NaN          `
# 9          NaN         NaN         NaN        NaN
# 10         NaN         NaN         NaN        NaN
# 11         NaN         NaN         NaN        NaN
# 12         NaN         NaN         NaN        NaN
# 13         NaN         NaN         NaN        NaN
# 14         NaN         NaN         NaN        NaN
# 15         NaN         NaN         NaN        NaN
# 16         NaN         NaN         NaN        NaN
# 17         NaN         NaN         NaN        NaN
# 18         NaN         NaN         NaN        NaN
# 19         NaN         NaN         NaN        NaN
# 20         NaN         NaN         NaN        NaN
# 21         NaN         NaN         NaN        NaN
# 22         NaN         NaN         NaN        NaN
# 23         NaN         NaN         NaN        NaN
# 24         NaN         NaN         NaN        NaN
# 25         NaN         NaN         NaN        NaN
# 26         NaN         NaN         NaN        NaN
# 27         NaN         NaN         NaN        NaN
# 28         NaN         NaN         NaN        NaN
# 29         NaN         NaN         NaN        NaN
# 30         NaN         NaN         NaN        NaN
# 31         NaN         NaN         NaN        NaN
# 32         NaN         NaN         NaN        NaN
# 33         NaN         NaN         NaN        NaN
# 34         NaN         NaN         NaN        NaN
# 35         NaN         NaN         NaN        NaN
# 36         NaN         NaN         NaN        NaN
# 37         NaN         NaN         NaN        NaN
# 38         NaN         NaN         NaN        NaN
# 39         NaN         NaN         NaN        NaN
# 40         NaN         NaN         NaN        NaN
# 41         NaN         NaN         NaN        NaN
# 42         NaN         NaN         NaN        NaN
# 43         NaN         NaN         NaN        NaN
# 44         NaN         NaN         NaN        NaN
# 45         NaN         NaN         NaN        NaN
# 46         NaN         NaN         NaN        NaN
# 47         NaN         NaN         NaN        NaN
# 48         NaN         NaN         NaN        NaN
# 49         NaN         NaN         NaN        NaN
# 50         NaN         NaN         NaN        NaN
# 51         NaN         NaN         NaN        NaN
# 52         NaN         NaN         NaN        NaN
# 53         NaN         NaN         NaN        NaN
# 54         NaN         NaN         NaN        NaN
# 55         NaN         NaN         NaN        NaN
# 56         NaN         NaN         NaN        NaN
# 57         NaN         NaN         NaN        NaN
# 58         NaN         NaN         NaN        NaN
# 59         NaN         NaN         NaN        NaN

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
tickers = df.iloc[:,0].to_list()
print(tickers)
# Out:
# ['XTSE/CP', 'XTSE/CCO', 'XTSE/MFC', 'XTSE/SLF', 'XTSE/MG', 'XTSE/CNQ', 'XTSE/RY', 'XTSE/TD', 'XTSE/BHC', 'XTSE/OTEX', 'XTSE/CM', 'XTSE/TRI', 'XTSE/RCI_B', 'XTSE/ENB', 'XTSE/BMO', 'XTSE/BNS', 'XTSE/BAM_A', 'XTSE/GIL', 'XTSE/CNR', 'XTSE/CAE', 'XTSE/ABX', 'XTSE/SJR_B', 'XTSE/IMO', 'XTSE/AEM', 'XTSE/WCN', 'XTSE/BCE', 'XTSE/ATD', 'XTSE/TRP', 'XTSE/SU', 'XTSE/WPM', 'XTSE/K', 'XTSE/CTC_A', 'XTSE/TECK_B', 'XTSE/BIP_UN', 'XTSE/QSR', 'XTSE/FSV', 'XTSE/CVE', 'XTSE/WEED', 'XTSE/FNV', 'XTSE/PPL', 'XTSE/DOL', 'XTSE/AQN', 'XTSE/CAR_UN', 'XTSE/KL', 'XTSE/EMA', 'XTSE/FM', 'XTSE/NA', 'XTSE/WN', 'XTSE/FTS', 'XTSE/L', 'XTSE/MRU', 'XTSE/SNC', 'XTSE/T', 'XTSE/CCL_B', 'XTSE/CSU', 'XTSE/POW', 'XTSE/SAP', 'XTSE/SHOP', 'XTSE/NTR', 'XTSE/GIB_A']

#             XTSE/NTR - Close  XTSE/GIB_A - Close
# Date
# 2022-12-30             98.85              116.71
# 2023-01-02             98.85              116.71
# 2023-01-03             97.90              117.64
# 2023-01-04             97.01              116.53
# 2023-01-05            101.19              114.67
# 2023-01-06            103.98              113.86
# 2023-01-09            102.91              114.35
# 2023-01-10             99.80              114.53
# 2023-01-11             99.47              115.41
# 2023-01-12            101.98              116.10
# 2023-01-13            100.66              116.07
# 2023-01-16            100.66              116.39
# 2023-01-17            102.13              116.42
# 2023-01-18            104.45              116.67
# 2023-01-19            102.68              116.23
# 2023-01-20            105.48              116.87
# 2023-01-23            105.80              117.16
# 2023-01-24            105.27              117.39
# 2023-01-25            106.09              114.18
# 2023-01-26            108.91              114.04
# 2023-01-27            107.56              113.00
# 2023-01-30            106.66              113.95
# 2023-01-31            110.14              114.04
# 2023-02-01            111.12              118.71
# 2023-02-02            112.45              118.50
# 2023-02-03            111.17              122.05
# 2023-02-06            111.19              122.09
# 2023-02-07            108.82              122.74
# 2023-02-08            105.21              123.55
# 2023-02-09            105.76              123.77
#
# [30 rows x 60 columns]

# %% [markdown]
# ### Finding daily return

# %%
from datetime import datetime, time
last_tday = datetime.today()
prev_bday = last_tday-pd.tseries.offsets.BDay(1)
print(prev_bday)

data = quandl.get(tickers, start_date=prev_bday, end_date=last_tday, column_index = 4)
display(data)
# please note that data may return blank when the closing price of the day is not yet available.
# Out:
# 2023-02-08 22:20:35.716521
#             XTSE/CP - Close  XTSE/CCO - Close  XTSE/MFC - Close  \
# Date
# 2023-02-08           104.45             36.76             26.09
# 2023-02-09           104.54             38.44             26.13
#
#             XTSE/SLF - Close  XTSE/MG - Close  XTSE/CNQ - Close  \
# Date
# 2023-02-08             67.44            87.34             79.74
# 2023-02-09             68.26            86.97             79.32
#
#             XTSE/RY - Close  XTSE/TD - Close  XTSE/BHC - Close  \
# Date
# 2023-02-08           139.55            92.88             10.18
# 2023-02-09           139.25            92.67              9.79
#
#             XTSE/OTEX - Close  ...  XTSE/MRU - Close  XTSE/SNC - Close  \
# Date                           ...
# 2023-02-08              47.61  ...             69.87             30.06
# 2023-02-09              48.41  ...             70.66             30.17
#
#             XTSE/T - Close  XTSE/CCL_B - Close  XTSE/CSU - Close  \
# Date
# 2023-02-08           28.09               63.79           2376.30
# 2023-02-09           27.03               62.98           2372.48
#
#             XTSE/POW - Close XTSE/SAP - Close  XTSE/SHOP - Close  \
# Date
# 2023-02-08             35.49            35.88              66.98
# 2023-02-09             35.63            35.29              66.86
#
#             XTSE/NTR - Close  XTSE/GIB_A - Close
# Date
# 2023-02-08            105.21              123.55
# 2023-02-09            105.76              123.77
#
# [2 rows x 60 columns]

# %% [markdown]
# On trading days, the TSX opens at 9:30am and closes at 4:00pm.  Given that some data providers may delay their data feed as much as 15 mins, we will program our app to capture the closing value at 4:15pm to be safe.

# %%
# We import the datatime package so we can use some datetime functions.  
# In this example, we will need the function .today to get today's date.
now = datetime.now()

# assume the market will close at 4pm and data will become available at 16:15 the day of
market_close_time = now.replace(hour=19, minute=15, second=0, microsecond=0)

# If the script is run after 16:15, last_tday is today
if now > market_close_time:
    last_tday = datetime.today()
    last_tday_minus1 = last_tday-pd.tseries.offsets.BDay(1)

#otherwise, last_tday is the previous business day
else:
    last_tday = datetime.today()-pd.tseries.offsets.BDay(1)
    last_tday_minus1 = last_tday-pd.tseries.offsets.BDay(1)

data = quandl.get(tickers, start_date=last_tday_minus1, end_date=last_tday, column_index = 4)
display(data)
# Out:
#             XTSE/CP - Close  XTSE/CCO - Close  XTSE/MFC - Close  \
# Date
# 2023-02-08           104.45             36.76             26.09
# 2023-02-09           104.54             38.44             26.13
#
#             XTSE/SLF - Close  XTSE/MG - Close  XTSE/CNQ - Close  \
# Date
# 2023-02-08             67.44            87.34             79.74
# 2023-02-09             68.26            86.97             79.32
#
#             XTSE/RY - Close  XTSE/TD - Close  XTSE/BHC - Close  \
# Date
# 2023-02-08           139.55            92.88             10.18
# 2023-02-09           139.25            92.67              9.79
#
#             XTSE/OTEX - Close  ...  XTSE/MRU - Close  XTSE/SNC - Close  \
# Date                           ...
# 2023-02-08              47.61  ...             69.87             30.06
# 2023-02-09              48.41  ...             70.66             30.17
#
#             XTSE/T - Close  XTSE/CCL_B - Close  XTSE/CSU - Close  \
# Date
# 2023-02-08           28.09               63.79           2376.30
# 2023-02-09           27.03               62.98           2372.48
#
#             XTSE/POW - Close XTSE/SAP - Close  XTSE/SHOP - Close  \
# Date
# 2023-02-08             35.49            35.88              66.98
# 2023-02-09             35.63            35.29              66.86
#
#             XTSE/NTR - Close  XTSE/GIB_A - Close
# Date
# 2023-02-08            105.21              123.55
# 2023-02-09            105.76              123.77
#
# [2 rows x 60 columns]

# %% [markdown]
# #### Calculate performance

# %%
pct_change = (data.iloc[1,:] - data.iloc[0,:])/data.iloc[0,:]
print(pct_change)
# Out:
# XTSE/CP - Close           0.000862
# XTSE/CCO - Close          0.045702
# XTSE/MFC - Close          0.001533
# XTSE/SLF - Close          0.012159
# XTSE/MG - Close          -0.004236
# XTSE/CNQ - Close         -0.005267
# XTSE/RY - Close           -0.00215
# XTSE/TD - Close          -0.002261
# XTSE/BHC - Close          -0.03831
# XTSE/OTEX - Close         0.016803
# XTSE/CM - Close          -0.006136
# XTSE/TRI - Close          -0.01845
# XTSE/RCI_B - Close       -0.008513
# XTSE/ENB - Close         -0.004891
# XTSE/BMO - Close         -0.005708
# XTSE/BNS - Close         -0.001366
# XTSE/BAM_A - Not Found         NaN
# XTSE/GIL - Close         -0.021646
# XTSE/CNR - Close         -0.004688
# XTSE/CAE - Close         -0.019835
# XTSE/ABX - Close         -0.027969
# XTSE/SJR_B - Close        0.001012
# XTSE/IMO - Close          0.000287
# XTSE/AEM - Close         -0.020607
# XTSE/WCN - Close          0.002844
# XTSE/BCE - Close         -0.010604
# XTSE/ATD - Close          0.011995
# XTSE/TRP - Close         -0.007745
# XTSE/SU - Close          -0.004924
# XTSE/WPM - Close         -0.009535
# XTSE/K - Close           -0.015464
# XTSE/CTC_A - Close       -0.003879
# XTSE/TECK_B - Close      -0.004049
# XTSE/BIP_UN - Close       0.009075
# XTSE/QSR - Close          0.000442
# XTSE/FSV - Close         -0.000314
# XTSE/CVE - Close         -0.008765
# XTSE/WEED - Close        -0.166213
# XTSE/FNV - Close         -0.011505
# XTSE/PPL - Close         -0.008409
# XTSE/DOL - Close         -0.002023
# XTSE/AQN - Close         -0.015152
# XTSE/CAR_UN - Close       0.005492
# XTSE/KL - Close                NaN
# XTSE/EMA - Close          -0.00019
# XTSE/FM - Close          -0.001853
# XTSE/NA - Close           0.001877
# XTSE/WN - Close           0.006909
# XTSE/FTS - Close         -0.008506
# XTSE/L - Close            0.006427
# XTSE/MRU - Close          0.011307
# XTSE/SNC - Close          0.003659
# XTSE/T - Close           -0.037736
# XTSE/CCL_B - Close       -0.012698
# XTSE/CSU - Close         -0.001608
# XTSE/POW - Close          0.003945
# XTSE/SAP - Close         -0.016444
# XTSE/SHOP - Close        -0.001792
# XTSE/NTR - Close          0.005228
# XTSE/GIB_A - Close        0.001781
# dtype: object

# %% [markdown]
# #### Top 3 Gainers

# %%
gainers = pd.to_numeric(pct_change).nlargest(3)
print(gainers)
# Out:
# XTSE/CCO - Close     0.045702
# XTSE/OTEX - Close    0.016803
# XTSE/SLF - Close     0.012159
# dtype: float64

# %% [markdown]
# #### Bottom 3 Losers

# %%
losers = pd.to_numeric(pct_change).nsmallest(3)
print(losers)
# Out:
# XTSE/WEED - Close   -0.166213
# XTSE/BHC - Close    -0.038310
# XTSE/T - Close      -0.037736
# dtype: float64

# %% [markdown]
# ### 10 Most actively traded stocks
# The output should inlcude the tickers of the top 10 stocks with their trading volumnn of the day.
# Please sort the volumn from high to low.

# %%
data = quandl.get(tickers, start_date=last_tday, end_date=last_tday, column_index = 5)
sorted_data=data.sort_values(by=data.index.tolist(), axis=1, ascending=False)
colume_table=sorted_data.iloc[0][:10]
display(colume_table)
# Out:
# XTSE/SU - Volume      10342075.0
# XTSE/ABX - Volume     10262069.0
# XTSE/ENB - Volume      9555733.0
# XTSE/T - Volume        8956722.0
# XTSE/WEED - Volume     6119467.0
# XTSE/MFC - Volume      5545558.0
# XTSE/SHOP - Volume     4456563.0
# XTSE/CCO - Volume      3216769.0
# XTSE/CVE - Volume      3130488.0
# XTSE/RY - Volume       3103017.0
# Name: 2023-02-09 00:00:00, dtype: object

# %% [markdown]
# ## Adding SMS Notifications

# %% [markdown]
# Twilio is an amazing communication plug-in that can take your app to a new level.  You can send SNS, email, voice or even video messages to your subscribers.  Trial accounts are free to use and you can register here: https://www.twilio.com/try-twilio
# You shall receive $15 credit once signed up, and that shall be sufficient for you to complete your prototype.
#
# There is Twilio Helper Library which you must first download.  Again, I will suggest you to install this package through the Anaconda Environment.  You shall be able to run the code below once the package is installed successfully.

# %%
from twilio.rest import Client

# Your Account SID and Auth Token from twilio.com/console
# I masked it using environment variable 
account_sid = %env twilio_sid 
auth_token  = %env twilio_token

client = Client(account_sid, auth_token)
name = "Hank Huang 1007113874"
quote = name + "\nToday's market recap - " + last_tday.strftime('%Y-%m-%d') + "\nBottom 3 losers\n" + str(losers) + "Top 3 gainers" + str(gainers)

message = client.messages.create(
    to="+14168463541", #change this number to your verified phone number
    from_="+12393635284", #change this number to your trial twilio phone number
    body = quote)

print(message.sid)
# Out:
# SM8d7196da1fb325146b356f3bfb2b289d

# %% [markdown]
# Now you know how to create the code to display the EOD stock data.  The next step is to deploy the above code onto a cloud server.  Please note that this will be out of the scope of this class.  However, if you are eager to make this a working protogype, there are a few ways to do this.  You can either [run the python script in AWS EC2](https://medium.com/@praneeth.jm/running-python-scripts-on-an-aws-ec2-instance-8c01f9ee7b2f) and schedule it with code, or try AWS Lambda.  AWS Lambda is called severless, and is the newer way of running scripts based on events.  You may also want to consider [containerizing(using Docker)](https://runnable.com/docker/python/dockerize-your-python-application) the script and [deploy it into AWS.](https://aws.amazon.com/getting-started/hands-on/deploy-docker-containers/)
#
# There are probably simpler and better ways to deploy this as well.  I encourage you to explore and try things out.

# %% [markdown]
# ## Part 2 Generating trading signals

# %% [markdown]
# ### TA-Lib
# TA-Lib is an open-sourced library that consists of over 150 technical trading strategies.  This library is very popular among financial software developers.  You are going to pick out some strategies to try.  See http://mrjbq7.github.io/ta-lib/index.html for more information about this Python library.
#
# #### Installation
# Similar to the other Python packages that you've installed earlier.  In the command line, type
# ```$ pip install TA-Lib```
#
# If you experience trouble during installation, this article may help: [How to install Ta-Lib in Python](https://blog.quantinsti.com/install-ta-lib-python/#macos)
#
# For latest Macs(M1 chip), see instructions [here](https://stackoverflow.com/questions/66056725/is-it-possible-that-mac-m1-users-are-not-able-to-use-python-wrapper-for-ta-lib).

# %% [markdown]
# #### Impoart TA-Lib library

# %%
import talib
import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11288\3841618685.py in <module>
# ----> 1 import talib
#       2 import numpy
#
# ModuleNotFoundError: No module named 'talib'

# %%
ticker = 'XTSE/BMO'
data = quandl.get(ticker, start_date='2021-12-31', end_date='2022-12-31', column_index = 4)
display(data)

# %%
type(data)

# %%
# close = data.iloc[:,0].to_numpy()
close = data['Close'].values

# %%
close

# %%
type(close)

# %% [markdown]
# ### Using RSI as an example

# %%
from talib import RSI
output = RSI(close, timeperiod=14)
print(output)

# %%
output[-1]

# %% [markdown]
# ### Plotting the RSI

# %% [markdown]
# #### importing the plotting library

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(output)
plt.axhline(y=30, color='r', linestyle='-')
plt.axhline(y=70, color='b', linestyle='-')

# %%
plt.plot(data)

# %% [markdown]
# ### Using MACD as an example

# %%
from talib import MACD
macd, macdsignal, macdhist = MACD(close, fastperiod=12, slowperiod=26, signalperiod=9)

# %%
macdhist[-1]

# %%
plt.plot(macd)

plt.plot(macdsignal)

# %% [markdown]
# ### Real-time stock data
#
# https://www.alphavantage.co/
#
# ### Other technical indicators
# https://pypi.org/project/TA-Lib/

# %%
# dict of functions by group
talib.get_function_groups()
